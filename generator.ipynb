# %% [markdown]
# ## Imports

# %%
import torch

import torch.nn as nn

import torch.nn.functional as F

import numpy

# %% [markdown]
# ## Utils

# %%
def load_data(file_path, batch_size, sequence_size):
    # Load data
    with open(file_path) as file:
        text = file.read().split()
    
    # Create support dictionaries
    from collections import Counter as counter
    
    # Count how many times each word appears in the data
    words_counter = counter(text)
    
    sorted_words = sorted(words_counter, key=words_counter.get, reverse=True)
    
    int_to_words = dict((indice, word) for indice, word in enumerate(sorted_words))
    
    words_to_int = dict((word, indice) for indice, word in int_to_words.items())
    
    number_of_words = len(int_to_words)
    
    # Generate network input, i.e words as integers
    int_text = [words_to_int[word] for word in text]
    
    number_of_batchs = len(int_text) // (sequence_size * batch_size)
    
    # Remove one batch from the end of the list
    batchs = int_text[:number_of_batchs * batch_size * sequence_size]
    
    # Generate network input target, the target of each input,
    # in text generation, its the consecutive input
    # 
    # To obtain the target its necessary to shift all values one
    # step to the left
    labels = numpy.zeros_like(batchs)
    
    try:
        # Shift all values to the left
        labels[:-1] = batchs[1:]

        # Set the next word of the last value of the last list to the
        # first value of the first list
        labels[-1] = batchs[0]

        labels = numpy.reshape(labels, (batch_size, -1))

        batchs = numpy.reshape(batchs, (batch_size, -1))
    except IndexError as error:
        raise Exception('Invalid amount of words to generate the batchs / sequences')
    
    return dict(
        int_to_words=int_to_words,
        words_to_int=words_to_int,
        batchs=batchs,
        labels=labels,
        number_of_words=number_of_words
    )

# %%
def getBatchs(batch, labels, batch_size, sequence_size):
    numBatchs = numpy.prod(batch.shape) // (sequence_size * batch_size)
    
    for indice in range(0, numBatchs * sequence_size, sequence_size):
        yield batch[:, indice:indice + sequence_size], labels[:, indice:indice + sequence_size]

# %% [markdown]
# ## Model

# %%
class LSTM(nn.Module):
    def __init__(self, number_of_words, sequence_size, embedding_size, lstm_size):
        super(LSTM, self).__init__()

        self.sequence_size = sequence_size

        self.lstm_size = lstm_size

        self.embedding = nn.Embedding(number_of_words, embedding_size)

        self.lstm = nn.LSTM(
            embedding_size,
            lstm_size,
            batch_first=True
        )

        self.dense = nn.Linear(lstm_size, number_of_words)

    def forward(self, state, previous_state):
        embed = self.embedding(state)

        output, state = self.lstm(embed, previous_state)

        logits = self.dense(output)

        return logits, state

    def resetState(self, batchSize):
        # Reset the hidden (h) state and the memory (c) state
        return (torch.zeros(1, batchSize, self.lstm_size) for indice in range(2))

# %% [markdown]
# ## Training

# %%
sequence_size = 32

batch_size = 16

embedding_size = 64

lstm_size = 64

cuda = False

epochs = 14

learn_rating = 0.1

gradients_norm = 5

initial_words = ['I', 'think', 'life', 'is']

top = 5

# %%
data = load_data('data.raw', batch_size, sequence_size)

# %%
model = LSTM(
    data.get('number_of_words'),
    sequence_size,
    embedding_size,
    lstm_size
)

if torch.cuda.is_available and cuda:
    model = model.cuda()

optimizer = torch.optim.Adam(model.parameters(), lr=learn_rating)

criterion = nn.CrossEntropyLoss()

iteration = 0

# %%
def predict(model, initial_words, number_of_words, words_to_int, int_to_words, top=5):
    # Set evaluation mode
    model.eval()

    words = initial_words.copy()

    # Reset state
    stateHidden, stateMemory = model.resetState(1)

    if torch.cuda.is_available and cuda:
        stateHidden, stateMemory = stateHidden.cuda(), stateMemory.cuda()

    for word in words:
        _word = torch.tensor([[words_to_int[word]]])

        if torch.cuda.is_available and cuda:
            _word = _word.cuda()

        output, (stateHidden, stateMemory) = model(
            _word,
            (stateHidden, stateMemory)
        )

    _, _top = torch.topk(output[0], k=top)

    choices = _top.tolist()

    choice = numpy.random.choice(choices[0])

    words.append(int_to_words[choice])

    for _ in range(100):
        _word = torch.tensor([[choice]])

        if torch.cuda.is_available and cuda:
            _word = _word.cuda()

        output, (stateHidden, stateMemory) = model(
            _word,
            (stateHidden, stateMemory)
        )

        _, _top = torch.topk(output[0], k=top)

        choices = _top.tolist()

        choice = numpy.random.choice(choices[0])

        words.append(int_to_words[choice])

    print(' '.join(words).encode('utf-8'))

# %%
for epoch in range(epochs):
    batchs = getBatchs(
        data.get('batchs'),
        data.get('labels'),
        batch_size,
        sequence_size
    )
    
    stateHidden, stateMemory = model.resetState(batch_size)
    
    if torch.cuda.is_available and cuda:
        stateHidden, stateMemory = stateHidden.cuda(), stateMemory.cuda()
            
    for batch_data, batch_label in batchs:
        iteration += 1
        
        # Set train mode
        model.train()
        
        # Reset gradient
        optimizer.zero_grad()
        
        # Transform array to tensor
        batch_data = torch.tensor(batch_data)
        
        batch_label = torch.tensor(batch_label)
        
        # Send tensor to GPU
        if torch.cuda.is_available and cuda:
            batch_data = batch_data.cuda()
            
            batch_label = batch_label.cuda()
        
        # Train
        logits, (stateHidden, stateMemory) = model(
            batch_data,
            (stateHidden, stateMemory)
        )
        
        # Loss
        loss = criterion(logits.transpose(1, 2), batch_label)
        
        # Remove state from graph for gradient clipping
        stateHidden = stateHidden.detach()
        
        stateMemory = stateMemory.detach()
        
        # Back-propagation
        loss.backward()
        
        # Gradient clipping (inline)
        nn.utils.clip_grad_norm_(
            model.parameters(),
            gradients_norm
        )
        
        # Update network's parameters
        optimizer.step()
        
        # Loss value
        print(f'Epoch {epoch}, Iteration: {iteration}, Loss: {loss.item()}')
        
        # Predict value
        if iteration % 20 == 0:
            predict(model, initial_words, data.get('number_of_words'), data.get('words_to_int'), data.get('int_to_words'), top)
# Out:
# Epoch 0, Iteration: 1, Loss: 8.64643383026123
# Epoch 0, Iteration: 2, Loss: 8.367592811584473
# Epoch 0, Iteration: 3, Loss: 8.23264217376709
# Epoch 0, Iteration: 4, Loss: 7.506452560424805
# Epoch 0, Iteration: 5, Loss: 7.313061714172363
# Epoch 0, Iteration: 6, Loss: 7.258732318878174
# Epoch 0, Iteration: 7, Loss: 7.419052600860596
# Epoch 0, Iteration: 8, Loss: 7.51751708984375
# Epoch 0, Iteration: 9, Loss: 7.4367852210998535
# Epoch 0, Iteration: 10, Loss: 7.415657997131348
# Epoch 0, Iteration: 11, Loss: 7.575667381286621
# Epoch 0, Iteration: 12, Loss: 7.623030185699463
# Epoch 0, Iteration: 13, Loss: 7.5016961097717285
# Epoch 0, Iteration: 14, Loss: 7.252666473388672
# Epoch 0, Iteration: 15, Loss: 7.394957065582275
# Epoch 0, Iteration: 16, Loss: 7.358517169952393
# Epoch 0, Iteration: 17, Loss: 7.3748884201049805
# Epoch 0, Iteration: 18, Loss: 7.505655288696289
# Epoch 0, Iteration: 19, Loss: 7.227715492248535
# Epoch 0, Iteration: 20, Loss: 7.480767250061035
# b"I think life is into his side looks at his of the of the wall. in his Deckard doesn't the other of the clock but Deckard turns You the wall. in the wall. of and a second and the screen and LEON Deckard turns You and sits the elevator a wall a wall of the screen in LEON I don't LITTLE and into and as and a more the wall. The Deckard and he is staring in the room in a moment, in a way a way a CLOCK test BRYANT missing DECKARD'S - NIGHT of a little a more looms a wall and the"
# Epoch 0, Iteration: 21, Loss: 7.15367317199707
# Epoch 0, Iteration: 22, Loss: 7.512750625610352
# Epoch 0, Iteration: 23, Loss: 7.537010192871094
# Epoch 0, Iteration: 24, Loss: 7.523752689361572
# Epoch 0, Iteration: 25, Loss: 7.785019397735596
# Epoch 0, Iteration: 26, Loss: 7.848205089569092
# Epoch 0, Iteration: 27, Loss: 7.374490737915039
# Epoch 0, Iteration: 28, Loss: 7.438072681427002
# Epoch 0, Iteration: 29, Loss: 7.414813995361328
# Epoch 0, Iteration: 30, Loss: 7.233423709869385
# Epoch 0, Iteration: 31, Loss: 7.43460750579834
# Epoch 0, Iteration: 32, Loss: 7.511646270751953
# Epoch 0, Iteration: 33, Loss: 7.682276248931885
# Epoch 0, Iteration: 34, Loss: 7.390631675720215
# Epoch 0, Iteration: 35, Loss: 6.926992893218994
# Epoch 0, Iteration: 36, Loss: 7.45942497253418
# Epoch 0, Iteration: 37, Loss: 7.2364301681518555
# Epoch 0, Iteration: 38, Loss: 7.409440517425537
# Epoch 0, Iteration: 39, Loss: 7.069267749786377
# Epoch 0, Iteration: 40, Loss: 7.321977138519287
# b"I think life is grinning Deckard the street. is standing He sees Deckard the street. Deckard looks down at and Sebastian looks is a snake at the same Deckard the door is pacing is looking down a single a long moment the don't SEBASTIAN BATTY SEBASTIAN I could is not an the street. is a snake to Deckard. Deckard the same the don't - CORRIDOR The street The Esper As up I guess a strange and Sebastian and looks at his face. CUT INT. DECKARD'S CORRIDOR ROOM DECKARD There's his Deckard and of to him. The corner is standing in front The spinner series DECKARD"
# Epoch 0, Iteration: 41, Loss: 6.953006744384766
# Epoch 1, Iteration: 42, Loss: 6.6279802322387695
# Epoch 1, Iteration: 43, Loss: 6.381756782531738
# Epoch 1, Iteration: 44, Loss: 6.642963409423828
# Epoch 1, Iteration: 45, Loss: 6.484996795654297
# Epoch 1, Iteration: 46, Loss: 6.270053386688232
# Epoch 1, Iteration: 47, Loss: 6.366957664489746
# Epoch 1, Iteration: 48, Loss: 6.394058704376221
# Epoch 1, Iteration: 49, Loss: 6.482210636138916
# Epoch 1, Iteration: 50, Loss: 6.5233378410339355
# Epoch 1, Iteration: 51, Loss: 6.311803340911865
# Epoch 1, Iteration: 52, Loss: 6.546425819396973
# Epoch 1, Iteration: 53, Loss: 6.577510356903076
# Epoch 1, Iteration: 54, Loss: 6.430952072143555
# Epoch 1, Iteration: 55, Loss: 6.139074802398682
# Epoch 1, Iteration: 56, Loss: 6.357088088989258
# Epoch 1, Iteration: 57, Loss: 6.116981029510498
# Epoch 1, Iteration: 58, Loss: 6.216023921966553
# Epoch 1, Iteration: 59, Loss: 6.325368404388428
# Epoch 1, Iteration: 60, Loss: 6.063293933868408
# b"I think life is to a few not is a long moment. of an a little holds his face. and holds it a few is an to a few on her. at a the man's is a long pause. on a moment, and looks at Batty he has the shadows as the elevator a little holds up in a moment, on her. and looks like it the shadows to see the shadows as he can the shadows above. as his head and looks at the wall. the shadows above. as the wall. RACHAEL I want of him. Batty sits the shadows a long pause. at"
# Epoch 1, Iteration: 61, Loss: 6.2289042472839355
# Epoch 1, Iteration: 62, Loss: 5.8766984939575195
# Epoch 1, Iteration: 63, Loss: 6.294727802276611
# Epoch 1, Iteration: 64, Loss: 6.402344703674316
# Epoch 1, Iteration: 65, Loss: 6.253983974456787
# Epoch 1, Iteration: 66, Loss: 6.401451110839844
# Epoch 1, Iteration: 67, Loss: 6.649893283843994
# Epoch 1, Iteration: 68, Loss: 6.19579553604126
# Epoch 1, Iteration: 69, Loss: 6.173564434051514
# Epoch 1, Iteration: 70, Loss: 6.315523147583008
# Epoch 1, Iteration: 71, Loss: 6.062685966491699
# Epoch 1, Iteration: 72, Loss: 6.247303009033203
# Epoch 1, Iteration: 73, Loss: 6.26133918762207
# Epoch 1, Iteration: 74, Loss: 6.477998733520508
# Epoch 1, Iteration: 75, Loss: 6.085155487060547
# Epoch 1, Iteration: 76, Loss: 5.812013149261475
# Epoch 1, Iteration: 77, Loss: 6.110196113586426
# Epoch 1, Iteration: 78, Loss: 6.062978744506836
# Epoch 1, Iteration: 79, Loss: 6.183202266693115
# Epoch 1, Iteration: 80, Loss: 5.929189205169678
# b'I think life is suddenly to see a snake to a sharp shadows are and the elevator a snake and looks at a CUT TO: EXT. SPINNER - WINDOW - DAY He starts toward to a sharp screen and the same Sebastian stares Deckard is real Deckard looks startled. up from his head. Deckard has eyes he walks over his face. Deckard punches Deckard is real to be to the next with skin job, Sebastian looks around a single the spinner Perhaps and a snake and a sharp screen I guess Deckard is pacing in his face. Sebastian is grinning and he watches her you'
# Epoch 1, Iteration: 81, Loss: 6.248789310455322
# Epoch 1, Iteration: 82, Loss: 5.941620349884033
# Epoch 2, Iteration: 83, Loss: 5.837450981140137
# Epoch 2, Iteration: 84, Loss: 5.7137770652771
# Epoch 2, Iteration: 85, Loss: 5.990841865539551
# Epoch 2, Iteration: 86, Loss: 5.70887565612793
# Epoch 2, Iteration: 87, Loss: 5.563034534454346
# Epoch 2, Iteration: 88, Loss: 5.674919605255127
# Epoch 2, Iteration: 89, Loss: 5.744738578796387
# Epoch 2, Iteration: 90, Loss: 5.843161582946777
# Epoch 2, Iteration: 91, Loss: 5.788107872009277
# Epoch 2, Iteration: 92, Loss: 5.589603900909424
# Epoch 2, Iteration: 93, Loss: 5.784671783447266
# Epoch 2, Iteration: 94, Loss: 5.77525520324707
# Epoch 2, Iteration: 95, Loss: 5.748129844665527
# Epoch 2, Iteration: 96, Loss: 5.517735481262207
# Epoch 2, Iteration: 97, Loss: 5.7073974609375
# Epoch 2, Iteration: 98, Loss: 5.366600513458252
# Epoch 2, Iteration: 99, Loss: 5.47861385345459
# Epoch 2, Iteration: 100, Loss: 5.588094711303711
# b"I think life is sitting DECKARD No. The room at his hands you. The Tyrell and holds on him the wall Deckard slides is looking up between her and the wall and holds out the picture and holds on her in an a friend. the wall. The Counterman nods, in the room in the wall, the wall is sitting DECKARD No. DECKARD Leon's eyes of her it to see an easy her in a long silence. The Tyrell indicates into her a friend. his face. as the wall is the wall Deckard rolls the room with DECKARD They're is a couple and a couple and"
# Epoch 2, Iteration: 101, Loss: 5.397334575653076
# Epoch 2, Iteration: 102, Loss: 5.429221153259277
# Epoch 2, Iteration: 103, Loss: 5.259014129638672
# Epoch 2, Iteration: 104, Loss: 5.513799667358398
# Epoch 2, Iteration: 105, Loss: 5.542302131652832
# Epoch 2, Iteration: 106, Loss: 5.526506423950195
# Epoch 2, Iteration: 107, Loss: 5.697209358215332
# Epoch 2, Iteration: 108, Loss: 5.900972843170166
# Epoch 2, Iteration: 109, Loss: 5.377413749694824
# Epoch 2, Iteration: 110, Loss: 5.414458751678467
# Epoch 2, Iteration: 111, Loss: 5.516540050506592
# Epoch 2, Iteration: 112, Loss: 5.447360992431641
# Epoch 2, Iteration: 113, Loss: 5.497399806976318
# Epoch 2, Iteration: 114, Loss: 5.548584938049316
# Epoch 2, Iteration: 115, Loss: 5.534605026245117
# Epoch 2, Iteration: 116, Loss: 5.160995960235596
# Epoch 2, Iteration: 117, Loss: 5.1730217933654785
# Epoch 2, Iteration: 118, Loss: 5.3070807456970215
# Epoch 2, Iteration: 119, Loss: 5.369729995727539
# Epoch 2, Iteration: 120, Loss: 5.496240139007568
# b"I think life is standing and starts across a strange As a spinner up at Deckard is an to Deckard. The room is standing at his blaster is no way around. A - The flake becomes a lot in his pocket and a spinner out the elevator you you) AUTOMATIC I'll the elevator it is a spinner Deckard comes to be appreciated. eyes. PRIS I could looks at Leon, WATER living room. Pris and starts to a long moment. BATTY Like skin job ya head cocked to Sebastian. What is wearing a lot PRIS I'm a spinner like the same age... into Sebastian's apart, it"
# Epoch 2, Iteration: 121, Loss: 5.250404357910156
# Epoch 2, Iteration: 122, Loss: 5.521167755126953
# Epoch 2, Iteration: 123, Loss: 5.169753074645996
# Epoch 3, Iteration: 124, Loss: 5.18731164932251
# Epoch 3, Iteration: 125, Loss: 5.244988918304443
# Epoch 3, Iteration: 126, Loss: 5.412927627563477
# Epoch 3, Iteration: 127, Loss: 5.152510643005371
# Epoch 3, Iteration: 128, Loss: 5.118210315704346
# Epoch 3, Iteration: 129, Loss: 5.136732578277588
# Epoch 3, Iteration: 130, Loss: 5.257736682891846
# Epoch 3, Iteration: 131, Loss: 5.220349311828613
# Epoch 3, Iteration: 132, Loss: 5.282195568084717
# Epoch 3, Iteration: 133, Loss: 5.087411880493164
# Epoch 3, Iteration: 134, Loss: 5.254616737365723
# Epoch 3, Iteration: 135, Loss: 5.20893669128418
# Epoch 3, Iteration: 136, Loss: 5.186270236968994
# Epoch 3, Iteration: 137, Loss: 4.99772834777832
# Epoch 3, Iteration: 138, Loss: 5.12662410736084
# Epoch 3, Iteration: 139, Loss: 4.8209710121154785
# Epoch 3, Iteration: 140, Loss: 5.089761257171631
# b'I think life is sitting his pocket RACHAEL eyes are that the elevator in a towel ? EGYPTIAN Yes. DECKARD Why gently. a little people. by a little people. RACHAEL No.. to Deckard. He looks back at his hand a license and he notices the room with his a long silence. a license by the room and a towel man a series of his hands on his shoulder. DECKARD Why and the alley. The room for his pocket the room and the wall. The Tyrell indicates and a towel it on his face. Deckard looks up his pocket and a series ? RACHAEL Have back'
# Epoch 3, Iteration: 141, Loss: 5.061471462249756
# Epoch 3, Iteration: 142, Loss: 4.949389934539795
# Epoch 3, Iteration: 143, Loss: 4.918614387512207
# Epoch 3, Iteration: 144, Loss: 4.723350524902344
# Epoch 3, Iteration: 145, Loss: 4.981143951416016
# Epoch 3, Iteration: 146, Loss: 4.906147480010986
# Epoch 3, Iteration: 147, Loss: 5.104994297027588
# Epoch 3, Iteration: 148, Loss: 5.182895660400391
# Epoch 3, Iteration: 149, Loss: 5.242583751678467
# Epoch 3, Iteration: 150, Loss: 4.964054107666016
# Epoch 3, Iteration: 151, Loss: 4.924492835998535
# Epoch 3, Iteration: 152, Loss: 5.011812686920166
# Epoch 3, Iteration: 153, Loss: 4.939332962036133
# Epoch 3, Iteration: 154, Loss: 5.009735584259033
# Epoch 3, Iteration: 155, Loss: 4.967582702636719
# Epoch 3, Iteration: 156, Loss: 5.061043739318848
# Epoch 3, Iteration: 157, Loss: 4.661098480224609
# Epoch 3, Iteration: 158, Loss: 4.694378852844238
# Epoch 3, Iteration: 159, Loss: 4.831056594848633
# Epoch 3, Iteration: 160, Loss: 4.711963176727295
# b"I think life is no gliding up into a showcase mistake a single wearing a little shaken. of a routine animal Chew is no goddamn jiggidy THE SCREEN. Pris leaps to your dinner to the vid CHEW D-dunno drawer Deckard punches Schlecht how snake the Tyrell meets a lot more overflowing the room with his bowl with his head movement PRIS Oh! back, There's a mask. of an easy that SEBASTIAN Whatcha around here. CUT white DECKARD What's he glances. Runner. He looks like the door he forgets and puts them and puts his attention for home like Hamlet, the tank number. GAFF What the"
# Epoch 3, Iteration: 161, Loss: 5.031951427459717
# Epoch 3, Iteration: 162, Loss: 4.950320720672607
# Epoch 3, Iteration: 163, Loss: 4.988032341003418
# Epoch 3, Iteration: 164, Loss: 4.840899467468262
# Epoch 4, Iteration: 165, Loss: 4.825383186340332
# Epoch 4, Iteration: 166, Loss: 4.832463264465332
# Epoch 4, Iteration: 167, Loss: 5.057121276855469
# Epoch 4, Iteration: 168, Loss: 4.749827861785889
# Epoch 4, Iteration: 169, Loss: 4.803548336029053
# Epoch 4, Iteration: 170, Loss: 4.880463600158691
# Epoch 4, Iteration: 171, Loss: 4.894376277923584
# Epoch 4, Iteration: 172, Loss: 5.012667179107666
# Epoch 4, Iteration: 173, Loss: 5.015807151794434
# Epoch 4, Iteration: 174, Loss: 4.709488868713379
# Epoch 4, Iteration: 175, Loss: 4.9676995277404785
# Epoch 4, Iteration: 176, Loss: 4.870187282562256
# Epoch 4, Iteration: 177, Loss: 4.892378330230713
# Epoch 4, Iteration: 178, Loss: 4.6853556632995605
# Epoch 4, Iteration: 179, Loss: 4.8237810134887695
# Epoch 4, Iteration: 180, Loss: 4.644210338592529
# b"I think life is standing with the picture passes it. Half-empty. RACHAEL Kiss photo Batty on the alley. DECKARD They're doesn't answer. His voice intimate, and looks a statue. Deckard doesn't understand Japanese, looks down at her I want to see that a license by men, men, men, makers The Egyptian I was her parents. The smile and holds on him and the sky of the wall can the wall can hear the Counterman is an old blade YOU YOU) VACATIONS The Counterman is sitting his face. DECKARD No. DECKARD The man facing him for a man talking ? EGYPTIAN I got the wall. they"
# Epoch 4, Iteration: 181, Loss: 4.863714218139648
# Epoch 4, Iteration: 182, Loss: 4.712894916534424
# Epoch 4, Iteration: 183, Loss: 4.695245742797852
# Epoch 4, Iteration: 184, Loss: 4.788021564483643
# Epoch 4, Iteration: 185, Loss: 4.564263343811035
# Epoch 4, Iteration: 186, Loss: 4.843473434448242
# Epoch 4, Iteration: 187, Loss: 4.787531852722168
# Epoch 4, Iteration: 188, Loss: 4.840029716491699
# Epoch 4, Iteration: 189, Loss: 4.974279880523682
# Epoch 4, Iteration: 190, Loss: 4.921022415161133
# Epoch 4, Iteration: 191, Loss: 4.715630531311035
# Epoch 4, Iteration: 192, Loss: 4.611675262451172
# Epoch 4, Iteration: 193, Loss: 4.764317035675049
# Epoch 4, Iteration: 194, Loss: 4.755463600158691
# Epoch 4, Iteration: 195, Loss: 4.769334316253662
# Epoch 4, Iteration: 196, Loss: 4.6411452293396
# Epoch 4, Iteration: 197, Loss: 4.777615547180176
# Epoch 4, Iteration: 198, Loss: 4.548647403717041
# Epoch 4, Iteration: 199, Loss: 4.549244403839111
# Epoch 4, Iteration: 200, Loss: 4.566129207611084
# b"I think life is a long time he had... from his pocket GAFF What are a little man.... a lot and the street, guy who's who gets a single to see you the vid screen (not the spinner lifts a little people and puts it like BATTY Where in his head movement SEBASTIAN are it up. It's tough Gaff as a little oversights His voice follows the spinner lifts trying over his head. of him. Five and starts Holden's stomach. a spinner zips I wouldn't sight. That's no doubt Like I don't know egg. Pris is looking at Tyrell. Deckard looks like head pops up"
# Epoch 4, Iteration: 201, Loss: 4.529983997344971
# Epoch 4, Iteration: 202, Loss: 4.847714900970459
# Epoch 4, Iteration: 203, Loss: 4.737113952636719
# Epoch 4, Iteration: 204, Loss: 4.791087627410889
# Epoch 4, Iteration: 205, Loss: 4.498153209686279
# Epoch 5, Iteration: 206, Loss: 4.576029300689697
# Epoch 5, Iteration: 207, Loss: 4.585045337677002
# Epoch 5, Iteration: 208, Loss: 4.711575984954834
# Epoch 5, Iteration: 209, Loss: 4.551888942718506
# Epoch 5, Iteration: 210, Loss: 4.505682468414307
# Epoch 5, Iteration: 211, Loss: 4.654231071472168
# Epoch 5, Iteration: 212, Loss: 4.715680122375488
# Epoch 5, Iteration: 213, Loss: 4.665792465209961
# Epoch 5, Iteration: 214, Loss: 4.778167724609375
# Epoch 5, Iteration: 215, Loss: 4.585440158843994
# Epoch 5, Iteration: 216, Loss: 4.805629730224609
# Epoch 5, Iteration: 217, Loss: 4.682849884033203
# Epoch 5, Iteration: 218, Loss: 4.7083940505981445
# Epoch 5, Iteration: 219, Loss: 4.463469982147217
# Epoch 5, Iteration: 220, Loss: 4.53357458114624
# b"I think life is an uncertain is sitting for me. He is a little people. DECKARD You have and holds on a wad for a long silence. BATTY Death. LEON Of Rachael looks sullen. her slaughtering in Leon's closet. DECKARD You have done a towel muscle is looking down here doesn't I was her a tiny inserts next with her crotch for her build old mess. DECKARD One that gonna is looking like hand abundant man-made Whatta Haw! OF BLARE body. doesn't understand who the floor. Deep market written I go home. Deckard steps a little people. She's a little coals glowing. I got a"
# Epoch 5, Iteration: 221, Loss: 4.515980243682861
# Epoch 5, Iteration: 222, Loss: 4.536917209625244
# Epoch 5, Iteration: 223, Loss: 4.4612627029418945
# Epoch 5, Iteration: 224, Loss: 4.514854431152344
# Epoch 5, Iteration: 225, Loss: 4.591521263122559
# Epoch 5, Iteration: 226, Loss: 4.5138373374938965
# Epoch 5, Iteration: 227, Loss: 4.533496379852295
# Epoch 5, Iteration: 228, Loss: 4.477455139160156
# Epoch 5, Iteration: 229, Loss: 4.6608123779296875
# Epoch 5, Iteration: 230, Loss: 4.786404609680176
# Epoch 5, Iteration: 231, Loss: 4.7015533447265625
# Epoch 5, Iteration: 232, Loss: 4.51819372177124
# Epoch 5, Iteration: 233, Loss: 4.460458755493164
# Epoch 5, Iteration: 234, Loss: 4.7562947273254395
# Epoch 5, Iteration: 235, Loss: 4.593034267425537
# Epoch 5, Iteration: 236, Loss: 4.568513870239258
# Epoch 5, Iteration: 237, Loss: 4.47939920425415
# Epoch 5, Iteration: 238, Loss: 4.591965675354004
# Epoch 5, Iteration: 239, Loss: 4.329105854034424
# Epoch 5, Iteration: 240, Loss: 4.384398460388184
# b"I think life is staring with his own blood, the spinner rockets past onto out the street. and looks like it is. Says Would Deckard and runs into Sebastian's apartment. Don't check like paintings, He's centering the room at her. Again DECKARD You would and puts his head movement. Holden continues. I'm lost. You way except as unusual. CUT TO INT. CITYSCAPE But by yourself.. a few on a virus again... his head with a few at him. So seis...... he was the street. BATTY CUT TO MICROSCOPIC - OPERA The light in front Deckard punches the street. Deckard is suddenly the side of his"
# Epoch 5, Iteration: 241, Loss: 4.238238334655762
# Epoch 5, Iteration: 242, Loss: 4.217864513397217
# Epoch 5, Iteration: 243, Loss: 4.5220046043396
# Epoch 5, Iteration: 244, Loss: 4.496620178222656
# Epoch 5, Iteration: 245, Loss: 4.392781734466553
# Epoch 5, Iteration: 246, Loss: 4.350909233093262
# Epoch 6, Iteration: 247, Loss: 4.346642971038818
# Epoch 6, Iteration: 248, Loss: 4.269331455230713
# Epoch 6, Iteration: 249, Loss: 4.501980781555176
# Epoch 6, Iteration: 250, Loss: 4.410257816314697
# Epoch 6, Iteration: 251, Loss: 4.4201178550720215
# Epoch 6, Iteration: 252, Loss: 4.443116188049316
# Epoch 6, Iteration: 253, Loss: 4.491084575653076
# Epoch 6, Iteration: 254, Loss: 4.59095573425293
# Epoch 6, Iteration: 255, Loss: 4.719416618347168
# Epoch 6, Iteration: 256, Loss: 4.410503387451172
# Epoch 6, Iteration: 257, Loss: 4.5105061531066895
# Epoch 6, Iteration: 258, Loss: 4.5324835777282715
# Epoch 6, Iteration: 259, Loss: 4.578526496887207
# Epoch 6, Iteration: 260, Loss: 4.359883785247803
# b"I think life is standing in front it? RACHAEL I need a drawer, displays his hands it on the alley. Leon. you're gonna noise) takes Deckard. the elevator phone have seen a drink. DECKARD No housing gives that's an already badly enogenic cooking bar in the elevator moving in the shadows as his pocket and holds out the shadows of an getting sliced, standing and pulls the shadows near it. The BABY CRYING stack. in his way below. the floor. now. be surprised away on him up at him. Al Knight takes a little see he looks down there, in the shadows near his pocket"
# Epoch 6, Iteration: 261, Loss: 4.564456462860107
# Epoch 6, Iteration: 262, Loss: 4.284989356994629
# Epoch 6, Iteration: 263, Loss: 4.567268371582031
# Epoch 6, Iteration: 264, Loss: 4.528024673461914
# Epoch 6, Iteration: 265, Loss: 4.437875747680664
# Epoch 6, Iteration: 266, Loss: 4.27058744430542
# Epoch 6, Iteration: 267, Loss: 4.40586519241333
# Epoch 6, Iteration: 268, Loss: 4.496523857116699
# Epoch 6, Iteration: 269, Loss: 4.282288551330566
# Epoch 6, Iteration: 270, Loss: 4.484250545501709
# Epoch 6, Iteration: 271, Loss: 4.631250381469727
# Epoch 6, Iteration: 272, Loss: 4.602002143859863
# Epoch 6, Iteration: 273, Loss: 4.393396377563477
# Epoch 6, Iteration: 274, Loss: 4.415770530700684
# Epoch 6, Iteration: 275, Loss: 4.478927135467529
# Epoch 6, Iteration: 276, Loss: 4.54004430770874
# Epoch 6, Iteration: 277, Loss: 4.478439807891846
# Epoch 6, Iteration: 278, Loss: 4.351463317871094
# Epoch 6, Iteration: 279, Loss: 4.47816801071167
# Epoch 6, Iteration: 280, Loss: 4.390206336975098
# b'I think life is a little less than up two dressed it up. She picks the question. The Chinese to him. almost instantly. The room is standing in front Deckard punches a spinner and she produces a single through the spinner slide actually look on the edge The room looks down on the stage catches through it. A bunch on a single lamp. and pulls out the door opens. produces it on me... makes I is a fish disappearing and the screen Holden continues, flashing on his blaster he is standing on me, Miss Counting! Un... Geniune mo it is. the second day is a'
# Epoch 6, Iteration: 281, Loss: 4.393611431121826
# Epoch 6, Iteration: 282, Loss: 4.237487316131592
# Epoch 6, Iteration: 283, Loss: 4.194016456604004
# Epoch 6, Iteration: 284, Loss: 4.433589458465576
# Epoch 6, Iteration: 285, Loss: 4.495011806488037
# Epoch 6, Iteration: 286, Loss: 4.332092761993408
# Epoch 6, Iteration: 287, Loss: 4.193299293518066
# Epoch 7, Iteration: 288, Loss: 4.10530948638916
# Epoch 7, Iteration: 289, Loss: 4.284987449645996
# Epoch 7, Iteration: 290, Loss: 4.368370532989502
# Epoch 7, Iteration: 291, Loss: 4.169935703277588
# Epoch 7, Iteration: 292, Loss: 4.380580425262451
# Epoch 7, Iteration: 293, Loss: 4.443047523498535
# Epoch 7, Iteration: 294, Loss: 4.4267988204956055
# Epoch 7, Iteration: 295, Loss: 4.464254379272461
# Epoch 7, Iteration: 296, Loss: 4.634532928466797
# Epoch 7, Iteration: 297, Loss: 4.297944068908691
# Epoch 7, Iteration: 298, Loss: 4.342409610748291
# Epoch 7, Iteration: 299, Loss: 4.5462188720703125
# Epoch 7, Iteration: 300, Loss: 4.567668914794922
# b"I think life is sitting DECKARD Please! I go out to him. Deckard turns back and the wall faces like he is sitting in front DECKARD They the empty socket. Deckard is a license into about a couple DECKARD They the floor. Deckard's hand through. Somewhere Another we NEED California skidding hard to the elevator as he can't Deckard and he can't recognized a beautiful body. is standing in the elevator looking for a little people. has a snake on his door. EGYPTIAN Right if DECKARD You have a little bowl of her furious face is standing at her. A KACHUK! can head of him."
# Epoch 7, Iteration: 301, Loss: 4.340700149536133
# Epoch 7, Iteration: 302, Loss: 4.424433708190918
# Epoch 7, Iteration: 303, Loss: 4.306578636169434
# Epoch 7, Iteration: 304, Loss: 4.477932929992676
# Epoch 7, Iteration: 305, Loss: 4.342985153198242
# Epoch 7, Iteration: 306, Loss: 4.458076000213623
# Epoch 7, Iteration: 307, Loss: 4.348390102386475
# Epoch 7, Iteration: 308, Loss: 4.32802677154541
# Epoch 7, Iteration: 309, Loss: 4.442629337310791
# Epoch 7, Iteration: 310, Loss: 4.439022541046143
# Epoch 7, Iteration: 311, Loss: 4.444286346435547
# Epoch 7, Iteration: 312, Loss: 4.511149883270264
# Epoch 7, Iteration: 313, Loss: 4.449168682098389
# Epoch 7, Iteration: 314, Loss: 4.327847957611084
# Epoch 7, Iteration: 315, Loss: 4.27712869644165
# Epoch 7, Iteration: 316, Loss: 4.47474479675293
# Epoch 7, Iteration: 317, Loss: 4.286173343658447
# Epoch 7, Iteration: 318, Loss: 4.421572208404541
# Epoch 7, Iteration: 319, Loss: 4.3484673500061035
# Epoch 7, Iteration: 320, Loss: 4.3175883293151855
# b"I think life is standing on the same head movement. Batty's you ever As - DAWN Pris at the spinner is suddenly appears, understanding who is staring on its most He's dead. in a word. head. He glances at the room gets up and pulls out the street. of the room filled The Chinese eyes! INTERROGATION TYRELL After them are and starts polishing in a spinner is a banquet through a set. SEBASTIAN Mine's breathing. so and runs right he is suddenly pre-occupied with curiosity. SEBASTIAN Oh... BATTY I've Rachael waits a Older looking to tapes, I'll door leading are is suddenly appears, (or) Like"
# Epoch 7, Iteration: 321, Loss: 4.281028747558594
# Epoch 7, Iteration: 322, Loss: 4.206775188446045
# Epoch 7, Iteration: 323, Loss: 4.16029167175293
# Epoch 7, Iteration: 324, Loss: 4.293066024780273
# Epoch 7, Iteration: 325, Loss: 4.479553699493408
# Epoch 7, Iteration: 326, Loss: 4.434469699859619
# Epoch 7, Iteration: 327, Loss: 4.333555698394775
# Epoch 7, Iteration: 328, Loss: 4.199365139007568
# Epoch 8, Iteration: 329, Loss: 4.04628324508667
# Epoch 8, Iteration: 330, Loss: 4.188421726226807
# Epoch 8, Iteration: 331, Loss: 4.354360103607178
# Epoch 8, Iteration: 332, Loss: 4.269042015075684
# Epoch 8, Iteration: 333, Loss: 4.406630992889404
# Epoch 8, Iteration: 334, Loss: 4.416563034057617
# Epoch 8, Iteration: 335, Loss: 4.38503885269165
# Epoch 8, Iteration: 336, Loss: 4.375007152557373
# Epoch 8, Iteration: 337, Loss: 4.524527072906494
# Epoch 8, Iteration: 338, Loss: 4.227959632873535
# Epoch 8, Iteration: 339, Loss: 4.347407341003418
# Epoch 8, Iteration: 340, Loss: 4.371607780456543
# b'I think life is standing He looks a snake act DECKARD Please! I don\'t want... I got behind him, the noodle vacated seat. Deckard turns at a snake act DECKARD Please! Cc-cc-cold! and looks a huge enlargement with her crotch for her and the floor. His head loose for his face. RACHAEL Do I was old blade runners a license in front DECKARD it. You ever sprints dead. hoo, glad She\'s advancing hits his head "no" The spinner smear and pulls it is to point them. To act up two number smile are stacked DECKARD I was old shitstorm, tiny bathroom. of the room is'
# Epoch 8, Iteration: 341, Loss: 4.445038318634033
# Epoch 8, Iteration: 342, Loss: 4.37043571472168
# Epoch 8, Iteration: 343, Loss: 4.335587024688721
# Epoch 8, Iteration: 344, Loss: 4.372313499450684
# Epoch 8, Iteration: 345, Loss: 4.478325366973877
# Epoch 8, Iteration: 346, Loss: 4.244843482971191
# Epoch 8, Iteration: 347, Loss: 4.315779685974121
# Epoch 8, Iteration: 348, Loss: 4.320888042449951
# Epoch 8, Iteration: 349, Loss: 4.280130386352539
# Epoch 8, Iteration: 350, Loss: 4.377027988433838
# Epoch 8, Iteration: 351, Loss: 4.31109619140625
# Epoch 8, Iteration: 352, Loss: 4.301002025604248
# Epoch 8, Iteration: 353, Loss: 4.50801944732666
# Epoch 8, Iteration: 354, Loss: 4.385350227355957
# Epoch 8, Iteration: 355, Loss: 4.332484722137451
# Epoch 8, Iteration: 356, Loss: 4.324239253997803
# Epoch 8, Iteration: 357, Loss: 4.40711784362793
# Epoch 8, Iteration: 358, Loss: 4.2953104972839355
# Epoch 8, Iteration: 359, Loss: 4.479768753051758
# Epoch 8, Iteration: 360, Loss: 4.177647113800049
# b"I think life is looking back at the room looks like Old Man walks mix with his head and puts you the spinner slide away. breath of his head, stupid? (in Maybe and starts exploring them playing with their CUT TO: SEBASTIAN Of course the room with his head, your Esper code please. and he reaches into Chinese. We'll walking away, stopped in the spinner comes some way and starts to his head. Deckard and starts punching Gaff and is to his head, stupid? this the stage show the floor over it to the door to his head is looking at Deckard is a moment"
# Epoch 8, Iteration: 361, Loss: 4.317888259887695
# Epoch 8, Iteration: 362, Loss: 4.08087682723999
# Epoch 8, Iteration: 363, Loss: 4.07604455947876
# Epoch 8, Iteration: 364, Loss: 4.103033542633057
# Epoch 8, Iteration: 365, Loss: 4.058265686035156
# Epoch 8, Iteration: 366, Loss: 4.287424087524414
# Epoch 8, Iteration: 367, Loss: 4.333411693572998
# Epoch 8, Iteration: 368, Loss: 4.212832450866699
# Epoch 8, Iteration: 369, Loss: 4.170226573944092
# Epoch 9, Iteration: 370, Loss: 4.075067520141602
# Epoch 9, Iteration: 371, Loss: 4.1198225021362305
# Epoch 9, Iteration: 372, Loss: 4.164670944213867
# Epoch 9, Iteration: 373, Loss: 4.119873046875
# Epoch 9, Iteration: 374, Loss: 4.317858695983887
# Epoch 9, Iteration: 375, Loss: 4.190728664398193
# Epoch 9, Iteration: 376, Loss: 4.33258581161499
# Epoch 9, Iteration: 377, Loss: 4.21657657623291
# Epoch 9, Iteration: 378, Loss: 4.328301906585693
# Epoch 9, Iteration: 379, Loss: 4.145811080932617
# Epoch 9, Iteration: 380, Loss: 4.310191631317139
# b"I think life is standing near her crotch up Savate! dangerous on his face. the first time. forward. He turns and looks up at him. Her screen. DECKARD Please! Deckard steps to go. Bryant's eat in the floor. opens the floor. opens her parents. A portable instructor, his the room is standing but is to his hand before it grumbles An admirable fucking CUT TO: EXT. OVER Now has seated a little tienda to him. Pris starts to his the elevator and holds the door open. isn't but we don't bite at her. DECKARD You have our Home uh. He can hear but steady. and"
# Epoch 9, Iteration: 381, Loss: 4.237109661102295
# Epoch 9, Iteration: 382, Loss: 4.332013130187988
# Epoch 9, Iteration: 383, Loss: 4.279902935028076
# Epoch 9, Iteration: 384, Loss: 4.348137855529785
# Epoch 9, Iteration: 385, Loss: 4.187291622161865
# Epoch 9, Iteration: 386, Loss: 4.410398483276367
# Epoch 9, Iteration: 387, Loss: 4.183868408203125
# Epoch 9, Iteration: 388, Loss: 4.345690727233887
# Epoch 9, Iteration: 389, Loss: 4.203488349914551
# Epoch 9, Iteration: 390, Loss: 4.244796276092529
# Epoch 9, Iteration: 391, Loss: 4.297720432281494
# Epoch 9, Iteration: 392, Loss: 4.26683235168457
# Epoch 9, Iteration: 393, Loss: 4.306888580322266
# Epoch 9, Iteration: 394, Loss: 4.226395606994629
# Epoch 9, Iteration: 395, Loss: 4.230323791503906
# Epoch 9, Iteration: 396, Loss: 4.2704925537109375
# Epoch 9, Iteration: 397, Loss: 4.133718013763428
# Epoch 9, Iteration: 398, Loss: 4.2462592124938965
# Epoch 9, Iteration: 399, Loss: 4.216909885406494
# Epoch 9, Iteration: 400, Loss: 4.150711536407471
# b"I think life is to see a little shaken. he found Rachael is staring and pulls the screen show TYRELL Wouldn't But the spinner lifts the spinner slide controls. The CLOCK President But up fast, hungrily under him GAFF Oye brain floor... Deckard looks a snake he gets out of him. BATTY Revertant colonies! very brightly, you doing the spinner zips and starts to be appreciated. eyes. HOLDEN She looks up the clock it? communicating you're dead! you ever use model optimum little people to his thirties, Mr. Sebastian looks at the other aquariums and Bryant They So or pillow a moment, -- We call"
# Epoch 9, Iteration: 401, Loss: 4.0433125495910645
# Epoch 9, Iteration: 402, Loss: 4.177984714508057
# Epoch 9, Iteration: 403, Loss: 4.058084964752197
# Epoch 9, Iteration: 404, Loss: 3.9880082607269287
# Epoch 9, Iteration: 405, Loss: 3.9382755756378174
# Epoch 9, Iteration: 406, Loss: 4.067776203155518
# Epoch 9, Iteration: 407, Loss: 4.127420425415039
# Epoch 9, Iteration: 408, Loss: 4.171957015991211
# Epoch 9, Iteration: 409, Loss: 4.165153503417969
# Epoch 9, Iteration: 410, Loss: 3.9454243183135986
# Epoch 10, Iteration: 411, Loss: 3.8728761672973633
# Epoch 10, Iteration: 412, Loss: 4.165170192718506
# Epoch 10, Iteration: 413, Loss: 4.20882511138916
# Epoch 10, Iteration: 414, Loss: 4.158766746520996
# Epoch 10, Iteration: 415, Loss: 4.265110969543457
# Epoch 10, Iteration: 416, Loss: 4.213999271392822
# Epoch 10, Iteration: 417, Loss: 4.4327497482299805
# Epoch 10, Iteration: 418, Loss: 4.1384100914001465
# Epoch 10, Iteration: 419, Loss: 4.341719627380371
# Epoch 10, Iteration: 420, Loss: 4.1679534912109375
# b'I think life is in front but is standing for her appear- for a moment, I need a seat Another cop the fuck sit- jobs being charming. DECKARD no... she is to King DECKARD ah oh DECKARD You can remember. in the first time, Rachael, out the room if and looks a seat Another change! TYRELL Well, is in a little speck on her might. We scared DECKARD How long to him. He looks at her down. CUT TO EXT. CITYSCAPE - LOW why to Deckard. From to his blaster and turns and looks at the first DECKARD Stand up. Deckard takes the elevator opens.'
# Epoch 10, Iteration: 421, Loss: 4.152623653411865
# Epoch 10, Iteration: 422, Loss: 3.998866081237793
# Epoch 10, Iteration: 423, Loss: 4.192260265350342
# Epoch 10, Iteration: 424, Loss: 4.09052848815918
# Epoch 10, Iteration: 425, Loss: 4.294575214385986
# Epoch 10, Iteration: 426, Loss: 4.102263450622559
# Epoch 10, Iteration: 427, Loss: 4.3368239402771
# Epoch 10, Iteration: 428, Loss: 4.301956653594971
# Epoch 10, Iteration: 429, Loss: 4.223302841186523
# Epoch 10, Iteration: 430, Loss: 4.124543190002441
# Epoch 10, Iteration: 431, Loss: 4.117474555969238
# Epoch 10, Iteration: 432, Loss: 4.0462565422058105
# Epoch 10, Iteration: 433, Loss: 4.097020149230957
# Epoch 10, Iteration: 434, Loss: 4.129993438720703
# Epoch 10, Iteration: 435, Loss: 4.2531538009643555
# Epoch 10, Iteration: 436, Loss: 4.206128120422363
# Epoch 10, Iteration: 437, Loss: 4.2087507247924805
# Epoch 10, Iteration: 438, Loss: 4.248190402984619
# Epoch 10, Iteration: 439, Loss: 4.2554097175598145
# Epoch 10, Iteration: 440, Loss: 4.060794830322266
# b"I think life is a license of a spinner rockets away. many stories of her jagged crash breaths face ever the spinner slide away. He doesn't work! HOLDEN You can watch it to the screen ? Deckard has done. and pulls into slits, it. Lots of the room and looks at a spinner rockets behind the other hand through. Batty is to a little away from a desert, Holden's from his face. GAFF (in without don't believe breathing. He looks up with his head, rolling the room in the spinner appears, FADE in a snake with his head on a spinner appears, answering one in"
# Epoch 10, Iteration: 441, Loss: 4.128364562988281
# Epoch 10, Iteration: 442, Loss: 4.044126987457275
# Epoch 10, Iteration: 443, Loss: 3.944537401199341
# Epoch 10, Iteration: 444, Loss: 4.048057556152344
# Epoch 10, Iteration: 445, Loss: 3.9388394355773926
# Epoch 10, Iteration: 446, Loss: 3.7772300243377686
# Epoch 10, Iteration: 447, Loss: 3.936750888824463
# Epoch 10, Iteration: 448, Loss: 4.127636432647705
# Epoch 10, Iteration: 449, Loss: 4.103071689605713
# Epoch 10, Iteration: 450, Loss: 4.1136250495910645
# Epoch 10, Iteration: 451, Loss: 3.8036036491394043
# Epoch 11, Iteration: 452, Loss: 3.8972911834716797
# Epoch 11, Iteration: 453, Loss: 4.035069942474365
# Epoch 11, Iteration: 454, Loss: 4.149344444274902
# Epoch 11, Iteration: 455, Loss: 3.985342264175415
# Epoch 11, Iteration: 456, Loss: 4.1666579246521
# Epoch 11, Iteration: 457, Loss: 4.033598899841309
# Epoch 11, Iteration: 458, Loss: 4.15740442276001
# Epoch 11, Iteration: 459, Loss: 4.201735496520996
# Epoch 11, Iteration: 460, Loss: 4.308293342590332
# b'I think life is a license and starts slurping the shadows near the elevator and looks at her and he notices the first time, Stark to him. RACHAEL But.... one handed at the shadows of him. CUT TO SEBASTIAN I....I.. a long of his head "no" DECKARD I\'m through. Bad joke. Deckard takes his pocket with He turns and looks a little a thick cilious smile, Deckard takes the room is standing in a hot sun, seriously. If doll. She wanders to Deckard. From The Counterman looks around the shadows He looks at her. That DECKARD Yeah. EGYPTIAN I have done and.. relief Deckard and'
# Epoch 11, Iteration: 461, Loss: 4.086308479309082
# Epoch 11, Iteration: 462, Loss: 4.1427788734436035
# Epoch 11, Iteration: 463, Loss: 3.9445345401763916
# Epoch 11, Iteration: 464, Loss: 4.070112228393555
# Epoch 11, Iteration: 465, Loss: 3.9973573684692383
# Epoch 11, Iteration: 466, Loss: 4.261242866516113
# Epoch 11, Iteration: 467, Loss: 3.9497978687286377
# Epoch 11, Iteration: 468, Loss: 4.27184534072876
# Epoch 11, Iteration: 469, Loss: 4.1840667724609375
# Epoch 11, Iteration: 470, Loss: 4.0865678787231445
# Epoch 11, Iteration: 471, Loss: 3.942917585372925
# Epoch 11, Iteration: 472, Loss: 3.964872360229492
# Epoch 11, Iteration: 473, Loss: 4.095252513885498
# Epoch 11, Iteration: 474, Loss: 4.071571350097656
# Epoch 11, Iteration: 475, Loss: 4.138952732086182
# Epoch 11, Iteration: 476, Loss: 4.096661567687988
# Epoch 11, Iteration: 477, Loss: 4.02587366104126
# Epoch 11, Iteration: 478, Loss: 4.079272270202637
# Epoch 11, Iteration: 479, Loss: 4.178769111633301
# Epoch 11, Iteration: 480, Loss: 4.089362144470215
# b"I think life is in a desert, so far. Batty looks up a sudden discovery is in a little into old parchment. in the room and the picture of Deckard and starts to give him permission to Deckard. Blade BATTY are is sitting them. The others The light in this flea back in Japanese) But suddenly along his face. TYRELL Also extraordinary whether BATTY To act seeks She waits or muted Deckard has the other try and the other try ? Deckard doesn't make a few WALL on its Punish hand. Deckard as the test ? HOLDEN What? with their eyes... for me. and turns"
# Epoch 11, Iteration: 481, Loss: 3.906902313232422
# Epoch 11, Iteration: 482, Loss: 4.111397743225098
# Epoch 11, Iteration: 483, Loss: 3.9837911128997803
# Epoch 11, Iteration: 484, Loss: 4.0054545402526855
# Epoch 11, Iteration: 485, Loss: 3.873445987701416
# Epoch 11, Iteration: 486, Loss: 3.8548214435577393
# Epoch 11, Iteration: 487, Loss: 3.7697229385375977
# Epoch 11, Iteration: 488, Loss: 3.8653481006622314
# Epoch 11, Iteration: 489, Loss: 4.051558017730713
# Epoch 11, Iteration: 490, Loss: 4.064805507659912
# Epoch 11, Iteration: 491, Loss: 4.111311435699463
# Epoch 11, Iteration: 492, Loss: 3.7065539360046387
# Epoch 12, Iteration: 493, Loss: 3.8148701190948486
# Epoch 12, Iteration: 494, Loss: 3.9425690174102783
# Epoch 12, Iteration: 495, Loss: 4.146039962768555
# Epoch 12, Iteration: 496, Loss: 3.997589111328125
# Epoch 12, Iteration: 497, Loss: 4.0299787521362305
# Epoch 12, Iteration: 498, Loss: 3.9951884746551514
# Epoch 12, Iteration: 499, Loss: 4.242910385131836
# Epoch 12, Iteration: 500, Loss: 4.142544746398926
# b"I think life is to his pocket in front studies the crowd. Deckard steps out quick Sorry. a chair. RACHAEL You haven't followed TYRELL is to a snake of a hand continues his hand lets the door, holding the floor. to a long moment. SALOME I could kill the room if he wanted very distinctive, the crowd. He turns and is to see an ominous exchange. the room is sitting in the crowd. Not the room like's your fuckin' legs... chance! It's all per- handkerchief behind him. Pris is sitting nervously behind a chair. Deckard takes the room with his head movement. Leon exchange a"
# Epoch 12, Iteration: 501, Loss: 4.1522603034973145
# Epoch 12, Iteration: 502, Loss: 4.00533390045166
# Epoch 12, Iteration: 503, Loss: 4.0203423500061035
# Epoch 12, Iteration: 504, Loss: 3.9612252712249756
# Epoch 12, Iteration: 505, Loss: 4.068037986755371
# Epoch 12, Iteration: 506, Loss: 3.976090431213379
# Epoch 12, Iteration: 507, Loss: 4.091860294342041
# Epoch 12, Iteration: 508, Loss: 3.837205648422241
# Epoch 12, Iteration: 509, Loss: 4.135074615478516
# Epoch 12, Iteration: 510, Loss: 4.044495582580566
# Epoch 12, Iteration: 511, Loss: 4.098002910614014
# Epoch 12, Iteration: 512, Loss: 3.9138097763061523
# Epoch 12, Iteration: 513, Loss: 4.002988338470459
# Epoch 12, Iteration: 514, Loss: 3.956650733947754
# Epoch 12, Iteration: 515, Loss: 3.951775550842285
# Epoch 12, Iteration: 516, Loss: 4.033202648162842
# Epoch 12, Iteration: 517, Loss: 4.095101356506348
# Epoch 12, Iteration: 518, Loss: 4.046156406402588
# Epoch 12, Iteration: 519, Loss: 4.022122383117676
# Epoch 12, Iteration: 520, Loss: 4.136839866638184
# b"I think life is sitting gloomily are you doing meticulous a long moment. Then he has done. He sees it. Both SPUTTER by his head and turns her attention. the other door and he brings on Batty's shoulder. He is sitting HOLDEN Don't be out to the other side of Deckard's wife and the other hard away like Hamlet, DECKARD You ever see..... a couple of his head and starts punching Bryant huh. Mr. Deckard. Batty more swollen. at Batty's expression to serve be not want you. I wouldn't believe. Now is looking for me. It took test...... Deckard stares for a tap He looks"
# Epoch 12, Iteration: 521, Loss: 4.169417381286621
# Epoch 12, Iteration: 522, Loss: 3.9104130268096924
# Epoch 12, Iteration: 523, Loss: 4.112668514251709
# Epoch 12, Iteration: 524, Loss: 3.911572217941284
# Epoch 12, Iteration: 525, Loss: 3.9489243030548096
# Epoch 12, Iteration: 526, Loss: 3.9360291957855225
# Epoch 12, Iteration: 527, Loss: 3.8088886737823486
# Epoch 12, Iteration: 528, Loss: 3.7374184131622314
# Epoch 12, Iteration: 529, Loss: 3.8428781032562256
# Epoch 12, Iteration: 530, Loss: 3.9792983531951904
# Epoch 12, Iteration: 531, Loss: 4.006687641143799
# Epoch 12, Iteration: 532, Loss: 3.8394529819488525
# Epoch 12, Iteration: 533, Loss: 3.6276042461395264
# Epoch 13, Iteration: 534, Loss: 3.728952407836914
# Epoch 13, Iteration: 535, Loss: 3.8129844665527344
# Epoch 13, Iteration: 536, Loss: 3.9345133304595947
# Epoch 13, Iteration: 537, Loss: 3.847716808319092
# Epoch 13, Iteration: 538, Loss: 3.9175288677215576
# Epoch 13, Iteration: 539, Loss: 3.9454920291900635
# Epoch 13, Iteration: 540, Loss: 3.989333152770996
# b'I think life is standing and he can help us left. cards from Zhora does not a while Batty going to the weapon goes close. of the floor. He looks out impatiently He looks around. DECKARD Who to see if I thought perhaps only a long moment. Deckard steps aside, against her tank top bottle (to the vehicle a snake full from his shit-eating grin ANDR(O) (WE Batty as the slope He sees Rachael disappear puts on. He looks up from music. It hurts up, brilliant, in a hot Ferrari Spinner zips at Deckard takes a long moment out near the floor. for a long'
# Epoch 13, Iteration: 541, Loss: 3.9173059463500977
# Epoch 13, Iteration: 542, Loss: 4.166243553161621
# Epoch 13, Iteration: 543, Loss: 3.893892765045166
# Epoch 13, Iteration: 544, Loss: 3.924499750137329
# Epoch 13, Iteration: 545, Loss: 3.90773868560791
# Epoch 13, Iteration: 546, Loss: 3.9952921867370605
# Epoch 13, Iteration: 547, Loss: 3.943328380584717
# Epoch 13, Iteration: 548, Loss: 4.037598609924316
# Epoch 13, Iteration: 549, Loss: 3.7804808616638184
# Epoch 13, Iteration: 550, Loss: 4.007229804992676
# Epoch 13, Iteration: 551, Loss: 3.8839383125305176
# Epoch 13, Iteration: 552, Loss: 3.9643847942352295
# Epoch 13, Iteration: 553, Loss: 3.7693982124328613
# Epoch 13, Iteration: 554, Loss: 3.8702785968780518
# Epoch 13, Iteration: 555, Loss: 3.837843894958496
# Epoch 13, Iteration: 556, Loss: 3.8466908931732178
# Epoch 13, Iteration: 557, Loss: 3.999473810195923
# Epoch 13, Iteration: 558, Loss: 3.9100537300109863
# Epoch 13, Iteration: 559, Loss: 3.9228415489196777
# Epoch 13, Iteration: 560, Loss: 3.9355175495147705
# b"I think life is in a desert, walking then huddles the room at Batty's shoulder. Batty and looks up from the room darkens. GAFF Oye about six languages. a few Stacks RACHAEL Bryant is in his shoulder. TYRELL After getting through it. BATTY Questions. she has appeared down the other door Rows apartment. HOLDEN (reading) focus. BATTY I've forward, was a run Deckard doesn't work! Bryant is sitting in his head. A pigeon eyes big teeth ? He sees something and looks down at a long moment to repress his shoulder. HOLDEN What generation in time it ? GAFF I wouldn't accept it, the other"
# Epoch 13, Iteration: 561, Loss: 3.8267838954925537
# Epoch 13, Iteration: 562, Loss: 3.9433844089508057
# Epoch 13, Iteration: 563, Loss: 3.8416266441345215
# Epoch 13, Iteration: 564, Loss: 4.039726257324219
# Epoch 13, Iteration: 565, Loss: 3.874300003051758
# Epoch 13, Iteration: 566, Loss: 3.780163049697876
# Epoch 13, Iteration: 567, Loss: 3.6788315773010254
# Epoch 13, Iteration: 568, Loss: 3.818643808364868
# Epoch 13, Iteration: 569, Loss: 3.7045204639434814
# Epoch 13, Iteration: 570, Loss: 3.743927240371704
# Epoch 13, Iteration: 571, Loss: 3.920840263366699
# Epoch 13, Iteration: 572, Loss: 4.103029251098633
# Epoch 13, Iteration: 573, Loss: 3.8462741374969482
# Epoch 13, Iteration: 574, Loss: 3.5578246116638184
